# %% [markdown]
# **PROYECTO FINAL**
#
# ![IMG_0833.png](data:image/png;base64,...)
#
#
#
# **Programación Orientada a Objetos**
#
#
# *INTEGRANTES:*
#
#
# VALERIA GERALDINE DE LA CRUZ MONTES
#
#
# DIANA FERNANDA ROBLES FLORES
#
#
# SAMANTHA CITLALLY CASTRO ROJAS
#
#
# JOSE ÁNGEL GARCÍA VALLE

# %% [markdown]
# ***DESEMPEÑO DE ROLES***
#
#
# **Lider del equipo:** Samantha Citally Castro Rojas
#
#
#
# **Desarrolladora lógica:** Diana Fernanda Robles Flores
#
#
# **Especialistas en documentación y pruebas:** Valeria Geraldine De La Cruz Montes
# y
# José Ángel García Valle
#
#
# - Entre todos los integrantes del equipo desarrollamos el código de nuestro programa , se trabajo de manera equitativa

# %% [markdown]
# **Análisis hormonal en mujeres con y sin Síndrome de Ovario Poliquístico (SOP)**

# %% [markdown]
# ***Descripcion del proyecto***
#
# Consiste en el desarrollo de una herramienta programada en Python con Programación Orientada a Objetos (POO) para analizar información clínica y hormonal de mujeres con y sin Síndrome de Ovario Poliquístico (SOP).
#
# - Predicción aproximada de la probabilidad de que una mujer presente SOP.
# - Comparación de valores hormonales entre grupos.
# - Generación de estadísticas que permiten identificar patrones o factores asociados.
# - Gestión de pacientes mediante una estructura modular basada en clases.
#
# La lógica del programa se fundamenta en POO mediante abstracción, encapsulamiento, herencia y polimorfismo, asegurando una arquitectura limpia, escalable y fácil de mantener.

# %% [markdown]
# ***Objetivo del sistema***
#
# - Desarrollar una herramienta capaz de:
#
# - Analizar datos ingresados por el usuario.
#
# - Clasificar registros según la presencia o ausencia de SOP.
#
# - Apoyar el análisis clínico con cálculos hormonales y métricas relevantes.
#
# - Representar estadísticas que muestren tendencias generales.
#
# Este proyecto utiliza una base de datos compuesta por múltiples variables clínicas y hormonales que incluyen edad, niveles hormonales (LH, FSH, AMH, TSH, PRL), medidas antropométricas y características clínicas.

# %% [markdown]
# ***Arquitectura del programa***
#
# 1. Abstracción y Encapsulamiento
#
# - Cada paciente se modela como un objeto Paciente.
#
# - Los atributos se mantienen privados para proteger la integridad de los datos.
#
# - El acceso se realiza mediante métodos controlados.
#
# 2. Herencia
#
# Se aplicó una jerarquía de clases:
#
# - BaseDatosPacientes (clase principal):
# Maneja la colección de pacientes: agregar, eliminar, filtrar registros.
#
# - BaseDatosSOP (subclase):
# Incluye métodos adicionales para cálculos hormonales y clasificación.
#
# - PacienteSOP (subclase):
# Especialización que incorpora métodos para predicción del riesgo de SOP.

# %% [markdown]
# ***Polimorfismo***
#
# El método de comparación hormonal puede trabajar con distintas hormonas:
#
# comparar("LH")
#
# comparar("FSH")
#
# comparar("AMH")
#
# El mismo método se adapta según la variable analizada, evitando duplicar código.

# %% [markdown]
# 4.***Flujo general del programa***
#
# - Carga de datos.
#
# - Creación de objetos Paciente.
#
# - Almacenamiento en la base de datos.
#
# - Ejecución de comparaciones hormonales.
#
# - Cálculo y visualización de resultados.

# %% [markdown]
# ***Ejemplo de uso de programa***
# - REGISTRO DE UN PACIENTE

# %%
from POO_SOP import BaseDatosPacientes

gestor = BaseDatosPacientes()
gestor.Agregar()  # Solicita datos por consola y guarda al paciente

# %% [markdown]
# ***Instrucciones de uso del programa***
#
#
# El programa permite analizar datos hormonales y características clínicas de una paciente para estimar la probabilidad de que presente Síndrome de Ovario Poliquístico (SOP). Para utilizar el sistema, el usuario ingresa o carga información clave como edad, niveles hormonales (LH, FSH, AMH, TSH, PRL) Y medidas clínicas. El flujo de uso consiste en ingresar los datos, almacenarlos y ejecutar los métodos de comparación y predicción para obtener análisis clínicos útiles sobre la probabilidad de SOP.
#
#
# El usuario puede realizar lo siguiente:
#
# Registrar nuevas pacientes creando objetos de la clase Paciente.
# Ingresar al numero de selección (1).
# Ingresar los datos de la paciente.
# Esperar el mensaje de confirmación de que la paciente fue agregada correctamente.
#
#
# Guardar los registros dentro de BaseDatosPacientes, que funciona como la base de datos del sistema. De aqui, se presentan dos opciones:
# Filtrar:
#
# Ingresar al numero de selección (2).
# Ingresar el nombre de la paciente que se busca.
# Esperar la impresión de los datos.
# Eliminar:
#
# Ingresar al numero de selección (3).
# Ingresar el nombre de la paciente que se quiere eliminar.
# Esperar el mensaje de confirmación de que la paciente fue eliminada correctamente.
#
# Aplicar el método de predicción contenido en la subclase PacienteSOP para obtener una probabilidad aproximada de SOP.
# Ingresar el numero de selección (4).
# Ingresar el nombre de la paciente.
# Esperar los resultados de si existe probabilidad de padecer SOP o no.
#
# Generar estadísticas hormonales que permiten identificar diferencias entre los grupos analizados.
# Ingresar el numero de selección (5).
# Seleccionar que grupo se quiere analizar:
# Grupo con SOP:
#
# Ingresar el numero de selección (1).
# Esperar los resultados de la cantidad de pacientes con SOP.
# Grupo sin SOP:
#
# Ingresar el numero de selección (2).
# Esperar los resultados de la cantidad de pacientes sin SOP.
#
# Ingresar el numero de selección (6) para salir del programa.

# %% [markdown]
# ***Decisiones del diseño***
#
# Se utilizaron clases para representar pacientes y administrar sus datos porque la POO permite organizar la información de forma clara y modular. Se eligieron diccionarios para almacenar los registros por su acceso rápido y sencillo. La predicción de SOP se implementó mediante comparaciones de rangos hormonales para mantener el sistema simple, didáctico y fácil de interpretar.

# %% [markdown]
# ***Descripción final del problema***
#
# El Síndrome de Ovario Poliquístico (SOP) es un trastorno hormonal común que requiere analizar varios indicadores clínicos al mismo tiempo, lo que dificulta su detección inicial. Para apoyar este proceso, se desarrolló un programa basado en Programación Orientada a Objetos que permite registrar pacientes y evaluar valores hormonales clave como FSH, LH, AMH, TSH, PRL, progesterona, ciclo menstrual y número de folículos.
#
# El sistema compara estos parámetros con rangos de referencia y calcula una probabilidad aproximada de SOP, facilitando un análisis preliminar. A través de clases que administran pacientes, cálculos y estadísticas, el programa ofrece una herramienta sencilla y funcional para organizar información y apoyar la identificación temprana del síndrome.
